# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# ## BASIC ETHICAL ISSUES

# %% [markdown]
# ## DATA IMPORTING:

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls "/content/gdrive/My Drive"
# Out:
#  장교
#  명진이
# '10 27 18 Startup Meeting.gdoc'
# '12-2293 (전재민).JPG'
#  180905-통역장교집중대비반A-1회차.zip
#  180906-통역장교집중대비반A-2회차.zip
# '2018 plate 몸통부분 (학생배포용).pdf'
# '데이터사이언티스트 에듀챌린지 2라운드 feedback.gdoc'
# 'AM205 topics.gdoc'
# 'Apr-17-2019 11-47-19.mp4'
# 'Apr-17-2019 11-49-21.mp4'
# 'Apr-17-2019 11-51-09.mp4'
#  calendar.png
#  Certificate_for_Summer_Job.docx.gdoc
# 'Colab Notebooks'
# 'Copy of WSO technical_interview_guide-1.pdf'
#  cs_concentration_spreadsheet_v1.1.7.xlsx
# 'Discuss an accomplishment or event, formal or informal that marked your transition from childhood to adulthood within your culture, community, or family.gdoc'
# 'diva - Column chart 1.gsheet'
#  diva.gslides
# 'diva - Line chart 1.gsheet'
# 'diva - Line chart 2.gsheet'
# 'diva - Pie chart 1.gsheet'
# 'Dr. Ko'
# 'Google Internship Questionnaire.gdoc'
#  Harvard
#  Holiday_Certificate_for_Summer_Job.docx
# 'I90 Receipt.pdf'
# 'Intake-Snapshots (2).pdf'
#  Internship_Agreement・Mr._Cheun_Jaemin.pdf
# 'Jaemincheun_green card (1).PDF'
#  Jaemin_Cheun_IB_Resume.docx
#  jaemin-cs-studyplan.gsheet
#  jcheunresume.doc
#  jcheunresume.doc.gdoc
#  Jobs
#  Keyboard.gsheet
# 'Keyboard Tracker.gsheet'
# 'Milestone 1.gdoc'
#  MJ_Thesis
# 'Model Documentation for Dumpling.io.gdoc'
#  MS_why_tech_banking.docx
# 'notice_44642999 (1).pdf'
#  passbolt_private.asc
# 'Questionnaire_for_Summer_Job-student(COE_application).docx'
# 'Questionnaire_for_Summer_Job-student(COE_application).docx.gdoc'
#  SAMPLE・Holiday_Certificate_for_Summer_Job.docx
# 'Schedule_for_COE_&_VISA(Rakuten).pdf'
#  SEASWordTemplate.docx
#  slides_ph_0806A.gslides
#  Startup
#  sublease-agreement.pdf
# 'SUNY Korea Essay Form.docx'
#  tmptotkism5.csv
# 'Understanding Frontend Development.gslides'
# 'Units 4.gdoc'
# 'Units 4.pdf'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'

# %% [markdown]
# ### TODO: Import data from csv into pandas dataframe

# %% [markdown]
# ### TODO: Augment weather data (Not important at this point)

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### TODO: Remove NA Values

# %% [markdown]
# ### TODO: Break Boston up into grid

# %% [markdown]
# ## EDA:

# %% [markdown]
# ### TODO: Distribution of crimes

# %% [markdown]
# ### TODO: Decide which crime to focus on

# %% [markdown]
# ## BASELINE MODELS

# %% [markdown]
# ### TODO: Random Forest

# %% [markdown]
# ### TODO: Naives Bayes

# %% [markdown]
# ### TODO: SVM

# %% [markdown]
# ## FANCY NETWORK:

# %% [markdown]
# ### TODO: Decide on Model

# %% [markdown]
# ### TODO: Train

# %% [markdown]
# ### TODO: Evaluation

# %% [markdown]
# ## PREDICTION ON TOP OF SOME MAP

# %% [markdown]
# ## EVALUATION / COMPARSION

# %% [markdown]
# ## CONCLUSION WITH MORE DISCUSSIONS ON ETHICAL ISSUES

# %% [markdown]
# ## REFERENCES
